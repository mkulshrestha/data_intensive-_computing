# %% [markdown]
# ### Mayank kulshrestha  (50291406)
# ### Nikhil lala (50290951)

# %% [markdown]
# ## Getting tweets with keyword "FLU"
#
# #### Reference : https://rtweet.info

# %%
# install.packages("twitteR","/anaconda3/lib/R/library")
# install.packages("rtweet","/anaconda3/lib/R/library")
library(openssl)
#used for secure transission and connection over transport layeer
library(httpuv)
#provides low level support for handling HTTP requests directly within R.
library(rtweet)
#To collect and organize twitter data over twitter's REST stream 
library(plyr)
#to split the twitter chunk data into smaller data frames
library(usmap)
#Obtain United States map data frames of varying region types
library(ggmap)
#A collection of functions to visualize spatial data and models on top of static maps from various online sources
library(maptools)
#To manupilating geographcical data.
library(ggplot2)
#to map varibles to aesthetics. To create declaritive graphics
library(stringr)
#To manupilate charecters within a string

#--------------making a connection to twitter----------------------!
tkn <- create_token(
  app = "mayank_lab1",
    consumer_key= "yxPeVtHxdc4JK5ymcz4vVmZuJ",
    consumer_secret= "OxPs4lxJTUUPUqsEkeVe4ZMMVRAioYBvJPoX3qeI1FlZX4UPwK",
    access_token="1094827502042865664-TSJR0Xh49AJHEZqnMiEP3hqoCuUBIk",
    access_secret= "gbgxe9fPq8WvV6uM2JvF9nNKKLJo8JjjGIokH09WmzwKe")

tw=search_tweets(q="flu", n=10000, token = tkn ,geocode=lookup_coords("usa"))

class(tw)
# 42.282731, -87.843778----------chicago, lake bluff,IL
#40.758895,-73.9873197----------new york city,NY
# 37.749767, -122.433147---------CA
# 31.179159, -98.579111------------TX
# 42.399625, -71.936844-------------MA
# 34.584596, -111.564004------------AZ
# tweets=searchTwitter("#flu",n=10000, since="2019-02-24", until="2019-02-25",retryOnRateLimit=10)
# d=twListToDF(tweets)
# Out:
# Loading required package: ggplot2
# Google's Terms of Service: https://cloud.google.com/maps-platform/terms/.
# Please cite ggmap if you use it! See citation("ggmap") for details.
# Loading required package: sp
# Checking rgeos availability: FALSE
#  	Note: when rgeos is not available, polygon geometry 	computations in maptools depend on gpclib,
#  	which has a restricted licence. It is disabled by default;
#  	to enable gpclib, type gpclibPermit()
# Searching for tweets...
# Finished collecting tweets!
# [1] "tbl_df"     "tbl"        "data.frame"

# %% [markdown]
# ## Finding latitude and longitude of the FLU data
# #### Reference : https://www.rdocumentation.org/packages/ggmap/versions/2.6.1/topics/geocode

# %%
register_google(key = "AIzaSyBxCFYJaFB_yoRmOcU8lNTHrUzbUK7IBZU")
tw=tw[which(tw$is_retweet==FALSE),]
df=geocode(tw$location, output = c("latlon"),
  source = c("google", "dsk"), override_limit = FALSE,
   nameType = c("long", "short"), data)
nrow(df)
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Vermont,+USA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=California,+USA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=California,+USA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Tuscaloosa,+AL&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Davenport,+IA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Ohio,+USA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=El+Paso,+TX&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Springfield,+MO&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Syracuse,+NY&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Syracuse,+NY&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Manchester+TN&key=xxx
# ...

# %%
df
# Out:
#      lon        lat
# 1     -72.57784 44.55880
# 2    -119.41793 36.77826
# 3    -119.41793 36.77826
# 4     -87.56917 33.20984
# 5     -90.57764 41.52364
# 6     -82.90712 40.41729
# 7    -106.48502 31.76188
# 8     -93.29230 37.20896
# 9     -76.14742 43.04812
# 10    -76.14742 43.04812
# 11    -86.08860 35.48174
# 12   -119.01871 35.37329
# 13   -119.01871 35.37329
# 14   -119.01871 35.37329
# 15   -102.55278 23.63450
# 16    -97.14667 31.54933
# 17    -82.90712 40.41729
# 18   -105.94007 35.68750
# 19    -74.00597 40.71278
# 20   -119.41793 36.77826
# 21   -119.41793 36.77826
# 22    -95.71289 37.09024
# 23    -95.71289 37.09024
# 24    -75.16522 39.95258
# 25    -88.99369 40.48420
# 26    -80.84313 35.22709
# 27    -85.13935 41.07927
# 28    -92.81036 38.13800
# 29   -118.41091 33.88474
# 30   -119.41793 36.77826
# ⋮    ⋮          ⋮
# 6510  -73.18567 40.73204
# 6511  -99.13321 19.43261
# 6512  -94.23334 36.01486
# 6513  -80.22135 40.51698
# 6514 -116.57650 53.93327
# ...

# %% [markdown]
# ## merging the longitude and latitude and saving the FLU data

# %%
nrow(df)
tw$lon=df$lon
tw$lat=df$lat
#4312

dd=tw
# nrow(dd)
completeVec <- complete.cases(dd[, "lon"])
dd=dd[completeVec,]
nrow(dd)
tw=dd
nrow(tw)
# save_as_csv(tw, "without_NA_Flu_tweets_4312.csv")
# Out:
# [1] 6539
# [1] 6445
# [1] 6445

# %% [markdown]
# ## Getting tweets with keyword "INFLUENZA"

# %%
tw_influenza=search_tweets(q="influenza", n=10000, token = tkn ,geocode=lookup_coords("usa"))
nrow(tw_influenza)
# Out:
# Searching for tweets...
# Finished collecting tweets!
# [1] 5530

# %% [markdown]
# ## Finding latitude and longitude of the INFLUENZA data
# #### Reference : https://www.rdocumentation.org/packages/ggmap/versions/2.6.1/topics/geocode

# %%
register_google(key = "AIzaSyBd1pWhE2KwsC0x4336cBg-OseVSFaMuvI")
tw_influenza=tw_influenza[which(tw_influenza$is_retweet==FALSE),]

df2=geocode(tw_influenza$location, output = c("latlon"),
  source = c("google", "dsk"), override_limit = FALSE,
   nameType = c("long", "short"), data)
nrow(df2)
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Canada&key=xxx-OseVSFaMuvI
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Reston,+VA&key=xxx-OseVSFaMuvI
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Mansfield,+Massachusetts&key=xxx-OseVSFaMuvI
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Marquette,+MI&key=xxx-OseVSFaMuvI
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=New+Orleans,+LA&key=xxx-OseVSFaMuvI
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Iowa,+USA&key=xxx-OseVSFaMuvI
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=New+York&key=xxx-OseVSFaMuvI
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=New+York&key=xxx-OseVSFaMuvI
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Edmonton,+Alberta&key=xxx-OseVSFaMuvI
# ...

# %% [markdown]
# ## Merging lattitude and longitude to the INFLUENZA data

# %%
nrow(tw_influenza)
#number of rows and columns in tw_influenza

tw_influenza$lon=df2$lon
tw_influenza$lat=df2$lat


supp_vec=complete.cases(tw_influenza[,"lon"])
tw_influenza=tw_influenza[supp_vec,]    #removing any row which has NA 

nrow(tw_influenza)
tw_influenza
# Out:
# [1] 2497
# [1] 2465
#      user_id             status_id           created_at
# 1    1033204996643336193 1102678422558466049 2019-03-04 21:13:17
# 2    2969656456          1102678057431777282 2019-03-04 21:11:50
# 3    2438435563          1102677898203463687 2019-03-04 21:11:12
# 4    20782724            1102677752082296833 2019-03-04 21:10:37
# 5    1026205188263235584 1102677061624225793 2019-03-04 21:07:52
# 6    776508578202947584  1102676435741954055 2019-03-04 21:05:23
# 7    732787392722182144  1102363188941725696 2019-03-04 00:20:39
# 8    732787392722182144  1100467807710519298 2019-02-26 18:49:05
# 9    25951460            1102675805027688450 2019-03-04 21:02:53
# 10   3312755852          1102675080209936386 2019-03-04 21:00:00
# 11   3312755852          1102652430553104384 2019-03-04 19:30:00
# 12   101802390           1102671338156769281 2019-03-04 20:45:08
# 13   913833311956545536  1099655180604395522 2019-02-24 13:00:00
# ...

# %% [markdown]
# ## Function that converts longitudes and latitudes into state names
# #### Reference:
# ##### https://stackoverflow.com/questions/8751497/latitude-longitude-coordinates-to-state-code-in-r

# %%
# After comsulting with the TA at the last minute i didnt use this function and instead used revgeo to get state names.


latlong2state <- function(pointsDF) {
    # Prepare SpatialPolygons object with one SpatialPolygon
    # per state (plus DC, minus HI & AK)
    states <- map('state', fill=TRUE, col="transparent", plot=FALSE)
    IDs <- sapply(strsplit(states$names, ":"), function(x) x[1])
    states_sp <- map2SpatialPolygons(states, IDs=IDs,
                     proj4string=CRS("+proj=longlat +datum=WGS84"))

    # Convert pointsDF to a SpatialPoints object 
    pointsSP <- SpatialPoints(pointsDF, 
                    proj4string=CRS("+proj=longlat +datum=WGS84"))

    # Use 'over' to get _indices_ of the Polygons object containing each point 
    indices <- over(pointsSP, states_sp)

    # Return the state names of the Polygons object containing each point
    stateNames <- sapply(states_sp@polygons, function(x) x@ID)
    stateNames[indices]
}

# %% [markdown]
# ## Converting longitude and latitude into statenames(adding a state_name column)
# #### Reference
# #### https://cran.r-project.org/web/packages/revgeo/revgeo.pdf

# %%
library(revgeo)
library(ggmap)
library(ggplot2)

#-----------for Data with keyword FLU------------------------------------
tw=read.csv("without_NA_Flu_tweets_4312.csv", header=TRUE)
testPoints= data.frame(x=tw$lon, y=tw$lat)
register_google(key = "AIzaSyBxCFYJaFB_yoRmOcU8lNTHrUzbUK7IBZU")
# testPoints
fg = revgeo(longitude=testPoints$x[0:500],latitude =testPoints$y[0:500], provider='google',API='AIzaSyBxCFYJaFB_yoRmOcU8lNTHrUzbUK7IBZU' ,output="frame",item="state")
tw=fg
tw$state_name=fg$state
tw$country=fg$country
tw=tw[which(tw$country=="United States"),]
tw
# save_as_csv(tw,"Flu_tweets_4312_with_state.csv") 


#-----------for Data with keyword INFLUENZA------------------------------

tw_influenza=read.csv("Influenza_tweets_2465.csv", header=TRUE)
testPoints = data.frame(x = tw_influenza$lon, y = tw_influenza$lat)
fg = revgeo(longitude=testPoints$x[0:100],latitude =testPoints$y[0:100], provider='google',API='AIzaSyBxCFYJaFB_yoRmOcU8lNTHrUzbUK7IBZU' ,output="frame",item="state")

#Reverse geocodes (looks up the address of) a longitude/latitude location using the Google Geocoding API

tw_influenza$state_name=fg$state_name
tw_influenza$country=fg$country
fg=fg[which(fg$country=="United States"),]
# save_as_csv(tw_influenza,"Influenza_tweets_2465_with_state.csv")   #(saved the data just to be safe and check its validity)
# Out:
# Google's Terms of Service: https://cloud.google.com/maps-platform/terms/.
# Please cite ggmap if you use it! See citation("ggmap") for details.
# [1] "Getting geocode data from Google: https://maps.googleapis.com/maps/api/geocode/json?latlng=29.7604267,-95.3698028&key=AIzaSyBxCFYJaFB_yoRmOcU8lNTHrUzbUK7IBZU"
# [1] "Getting geocode data from Google: https://maps.googleapis.com/maps/api/geocode/json?latlng=36.2082943,-115.9839147&key=AIzaSyBxCFYJaFB_yoRmOcU8lNTHrUzbUK7IBZU"
# [1] "Getting geocode data from Google: https://maps.googleapis.com/maps/api/geocode/json?latlng=44.977753,-93.2650108&key=AIzaSyBxCFYJaFB_yoRmOcU8lNTHrUzbUK7IBZU"
# [1] "Getting geocode data from Google: https://maps.googleapis.com/maps/api/geocode/json?latlng=37.2089572,-93.2922989&key=AIzaSyBxCFYJaFB_yoRmOcU8lNTHrUzbUK7IBZU"
# [1] "Getting geocode data from Google: https://maps.googleapis.com/maps/api/geocode/json?latlng=40.7127753,-74.0059728&key=AIzaSyBxCFYJaFB_yoRmOcU8lNTHrUzbUK7IBZU"
# ...

# %% [markdown]
# #### May use the new csv file for refering to data since the data will change if i run the above cells again

# %% [markdown]
# ## Removing tweets with no location

# %%
tw_flu=read.csv("Flu_tweets_4312_with_state.csv", header=TRUE)
tw_influenza=read.csv("Influenza_tweets_2465_with_state.csv", header=TRUE)


tw_flu=tw_flu[which(!tw_flu$state_name==""),]   #3580
tw_influenza=tw_influenza[which(!tw_influenza$state_name==""),]     #1374

# %% [markdown]
# ## Counting the frequency of tweets in each State with keyword "FLU"
# #### Reference
# #### https://www.rdocumentation.org/packages/usmap/versions/0.4.0/topics/plot_usmap

# %%
library(plyr)
library(ggplot2)
library(usmap)

df1=data.frame(count(tw_flu,"state_name"))

#-----------------state name to fips code----------------------
colnames(df1)[1]="state" # reference: https://stackoverflow.com/questions/7531868/how-to-rename-a-single-column-in-a-data-frame
# df
# jpeg("flu_world_map.jpg")
plot_usmap(data = df1 , values = "freq", lines = "black",labels=TRUE, label_color="black" ) + 
  scale_fill_continuous(name = "LEVEL OF ACTIVITY", label = scales::comma,low="white", high="red") + 
  theme(legend.position = "right")
# dev.off()
# Out:
# plot without title

# %% [markdown]
# ## Counting the frequency of tweets in each State with keyword "INFLUENZA"

# %%
df=data.frame(count(tw_influenza,"state_name"))

#-----------------state name to fips code----------------------
colnames(df)[1]="state"
# df

# jpeg("influenza_world_map.jpg")

plot_usmap(data = df , values = "freq", lines = "black",labels=TRUE, label_color="black" ) + 
  scale_fill_continuous(name = "LEVEL OF ACTIVITY", label = scales::comma,low="white", high="red") + 
  theme(legend.position = "right")
# dev.off()
# Out:
# plot without title

# %% [markdown]
# ## merging the frequency of tweets FLU & INFLUENZA
# #### reference : https://stackoverflow.com/questions/45688594/how-to-sum-values-of-matching-columns-while-merging-two-dataframes-in-r

# %%
library(data.table)
fg=rbindlist(list(df1, df), fill = TRUE)[,lapply(.SD, sum, na.rm = TRUE) , state]
# fg

# jpeg("combined_world_map.jpg")

plot_usmap(data = fg , values = "freq", lines = "black",labels=TRUE, label_color="black" ) + 
  scale_fill_continuous(name = "LEVEL OF ACTIVITY", label = scales::comma,low="white", high="blue") + 
  theme(legend.position = "right")
# dev.off()
# Out:
# plot without title

# %%
library(shiny)

runApp()
# Out:
# Listening on http://127.0.0.1:6968
